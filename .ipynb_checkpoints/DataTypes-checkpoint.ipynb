# %%
# print function
print("Hello, world!")
# Out:
# Hello, world!

# %%
# Integer
type(3)
# Out:
# int

# %%
# Float
type(1.)
# Out:
# float

# %%
# String
type("Manank")
# Out:
# str

# %%
# Boolean
type(False)
# Out:
# bool

# %%
# List
# type([1,2,3])
type(["Python", 3.14, True])
# Out:
# list

# %%
# Dictionary
type({"color": "blue"})
# Out:
# dict

# %%
# Tuple
type((1,2))
# Out:
# tuple

# %%
# Set
type({1,2})
# Out:
# set

# %%
# Addition
1+1
# Out:
# 2

# %%
# Subtract
2-1
# Out:
# 1

# %%
# Multiply
2*3
# Out:
# 6

# %%
# Divide
2 / 2
# Out:
# 1.0

# %%
# Floor Division
10//3
# Out:
# 3

# %%
# Modulus
10 % 3
# Out:
# 1

# %%
# Exponential
2 ** 3
# Out:
# 8
