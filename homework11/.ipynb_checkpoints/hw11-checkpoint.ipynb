# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
# Your code here (WITHOUT NUMPY! or any other modules/libraries/packages)
def kepler_third_time_from_semimajor(semimajor_axis):
    # Returns the orbital period based on semimajor axis using Kepler's Third Law
    orbital_period = (semimajor_axis**3)**0.5
    return orbital_period

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
# Your code here
print(kepler_third_time_from_semimajor(0.5))
print(kepler_third_time_from_semimajor(1.0))
print(kepler_third_time_from_semimajor(1.5))
# Out:
# 0.3535533905932738
# 1.0
# 1.8371173070873836

# %% [markdown]
# Import `numpy` in the cell below.

# %%
# Your code here
import numpy

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# Your comment (2 sentences)
# Numpy only needs to be called once in a jupyter notebook. This is because calling numpy once imports numpy to the
# entire file, so all pieces of code can access the imported package.

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
# Your code here
def kepler_third_time_from_semimajor_numpy(semimajor_axis):
    # Returns the oribtal period based on semimajor axis using numpy
    orbital_period = numpy.sqrt(semimajor_axis**3)
    return orbital_period

# %% [markdown]
# Import the `time` package in the cell below.

# %%
# Your code here
import time

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
# Your code here
start1 = time.time()
kepler_third_time_from_semimajor(5)
end1 = time.time()
print(end1-start1)
start2 = time.time()
kepler_third_time_from_semimajor_numpy(5)
end2 = time.time()
print(end2-start2)
# Out:
# 9.083747863769531e-05
# 0.007007122039794922

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Your comment here
# The first function is faster because python inherently has some operators which are quick to access.
# Numpy is slower because it needs to call a function in the package so it requires an extra step.

# %% [markdown]
# Define a **list** in the cell below that contains a least 1000 semi-major axis values.

# %%
# Your code here
semimajor_values = [i+1 for i in range(1000)]

# %% [markdown]
# With a **for** loop. Time each of your functions again with this new list.

# %%
# Your code here
start1=time.time()
for i in semimajor_values:
    kepler_third_time_from_semimajor(i)
end1 = time.time()
print("Not numpy: ", end1-start1)
start2=time.time()
for i in semimajor_values:
    kepler_third_time_from_semimajor_numpy(i)
end2 = time.time()
print("Numpy: ", end2-start2)
print((end2-start2)/(end1-start1))
# Out:
# Not numpy:  0.0004570484161376953
# Numpy:  0.0021250247955322266
# 4.649452269170579

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Your code here
# The function that doesn't use numpy is faster by about 3-4 times which might be because ** is inherent to python syntax.
# Numpy functions are slower due to requiring access to a package but they have many capabilities

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
# Your code here
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]
for i in range(len(temperatures)):
    if temperatures[i] < 350:
        print(radii[i])
# Out:
# 1.2
# 2.0

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
# Your code here
print(radii[:3])
# Out:
# [1.2, 0.8, 1.5]

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
# Your code here
planets = {}
for i in range(len(radii)):
    planets[i+1] = [radii[i], temperatures[i]]
print(planets)
# Out:
# {1: [1.2, 300], 2: [0.8, 400], 3: [1.5, 350], 4: [2.0, 280], 5: [1.0, 500], 6: [0.6, 450]}

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
# Your code here
planets["Mercury"] = planets.pop(0+1)
planets["Venus"] = planets.pop(1+1)
planets["Earth"] = planets.pop(2+1)
planets["Mars"] = planets.pop(3+1)
planets["Jupiter"] = planets.pop(4+1)
planets["Saturn"] = planets.pop(5+1)
print(planets)
# Out:
# {'Mercury': [1.2, 300], 'Venus': [0.8, 400], 'Earth': [1.5, 350], 'Mars': [2.0, 280], 'Jupiter': [1.0, 500], 'Saturn': [0.6, 450]}

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
# Your code here
small_planets = {}
for i in range(len(temperatures)):
    if radii[i]>=1.0 and radii[i] <= 2.0:
        small_planets[list(planets.keys())[i]] = planets[list(planets.keys())[i]]
print(small_planets)
# Out:
# {'Mercury': [1.2, 300], 'Earth': [1.5, 350], 'Mars': [2.0, 280], 'Jupiter': [1.0, 500]}

# %% [markdown]
# ## 3 NumPy
# With your 1,000,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
# Your code here
import random
semimajor_values = [random.randint(1,1000000000) for i in range(1000000)]

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
# Your code here
print(numpy.mean(semimajor_values))
print(numpy.median(semimajor_values))
print(numpy.min(semimajor_values))
print(numpy.max(semimajor_values))
# Out:
# 499817068.080825
# 499421778.5
# 123
# 999999065

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
# Your code here
print(numpy.std(semimajor_values))
# This function simply calculates the standard deviation of the values of the array.
# Out:
# 288659507.8552049

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
# Your code here
twod_array = []
twod_array.append(radii)
twod_array.append(temperatures)
print(twod_array)
# Out:
# [[1.2, 0.8, 1.5, 2.0, 1.0, 0.6], [300, 400, 350, 280, 500, 450]]

# %% [markdown]
# Use a for loop to print the value on the second row, third column.

# %%
# Your code here
print(twod_array[1][2])
# Out:
# 350

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, third column.

# %%
# Your code here
np_array = numpy.array(twod_array)
print(np_array[1][2])
# Out:
# 350.0

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
# Your code here
import matplotlib.pyplot as plt
semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
orbital_periods = []
for i in semi_major_axes:
    orbital_periods.append(kepler_third_time_from_semimajor(i))
plt.scatter(semi_major_axes, orbital_periods, label="Exoplanets")
plt.title("Orbital Periods of Exoplanets")
plt.xlabel("Semi-major Axes (AU)")
plt.ylabel("Orbital Periods (years)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
# Your code here
plt.bar(radii, temperatures, label="Planets")
plt.title("Equilibrium Temperatures vs. Radii")
plt.xlabel("Radii (R$_E$)")
plt.ylabel("Equilibrium Temperatures (K)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizonatally).

# %%
# Your code here
plt.subplot(1, 2,1)
plt.scatter(semi_major_axes, orbital_periods, label="Exoplanets")
plt.title("Orbital Periods of Exoplanets")
plt.xlabel("Semi-major Axes (AU)")
plt.ylabel("Orbital Periods (years)")
plt.legend(loc="lower right")
plt.subplot(1,2,2)
plt.bar(radii, temperatures, label="Planets")
plt.title("Equilibrium Temperatures vs. Radii")
plt.xlabel("Radii (R$_E$)")
plt.ylabel("Equilibrium Temperatures (K)")
plt.legend(loc="lower right")
plt.subplots_adjust(wspace=0.4)
plt.show()

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.

# %%
# Your code here
import keplerthird
print(keplerthird.kepler_third_time_from_semimajor(5))
# Out:
# 11.180339887498949
